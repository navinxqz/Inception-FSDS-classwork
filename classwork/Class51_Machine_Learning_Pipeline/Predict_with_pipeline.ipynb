# %%
import pickle as pkl
import numpy as np

# %%
pipe = pkl.load(open("titanic_pipe.pkl","rb"))

# %%
# Sample input
sample_input = np.array([3, "male", 22.0, 1, 0, 7.25, "S"], dtype=object).reshape(1, 7)

# %%
pipe.predict(sample_input)
# Out:
# d:\Inception FSDS\Inception-FSDS-classwork\classwork\Day26_Database\mongo\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# d:\Inception FSDS\Inception-FSDS-classwork\classwork\Day26_Database\mongo\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
