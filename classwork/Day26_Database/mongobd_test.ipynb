# %%
mongodb+srv://navinxqz:#Navin@477@cluster0.am2sy53.mongodb.net/?appName=Cluster0
# Out:
#   Cell In[2], line 1
#     mongodb+srv://navinxqz:#Navin@477@cluster0.am2sy53.mongodb.net/?appName=Cluster0
#                ^
# SyntaxError: invalid syntax

# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
data = pd.read_csv("D:\\Inception FSDS\\Inception-FSDS-classwork\\classwork\\Day26_Database\\healthcare-dataset-stroke-data.csv")

# %%
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
data.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
data.shape
# Out:
# (5110, 12)

# %%
data.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='str')

# %%
type(data)
# Out:
# pandas.DataFrame

# %%
data_dict = data.to_dict(orient="records")

# %%
data_dict
# Out:
# [{'id': 9046,
#   'gender': 'Male',
#   'age': 67.0,
#   'hypertension': 0,
#   'heart_disease': 1,
#   'ever_married': 'Yes',
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 228.69,
#   'bmi': 36.6,
#   'smoking_status': 'formerly smoked',
#   'stroke': 1},
#  {'id': 51676,
#   'gender': 'Female',
#   'age': 61.0,
#   'hypertension': 0,
#   'heart_disease': 0,
#   'ever_married': 'Yes',
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 202.21,
#   'bmi': nan,
#   'smoking_status': 'never smoked',
#   'stroke': 1},
#  {'id': 31112,
#   'gender': 'Male',
#   'age': 80.0,
#   'hypertension': 0,
#   'heart_disease': 1,
#   'ever_married': 'Yes',
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 105.92,
#   'bmi': 32.5,
#   'smoking_status': 'never smoked',
#   'stroke': 1},
#  {'id': 60182,
#   'gender': 'Female',
#   'age': 49.0,
#   'hypertension': 0,
#   'heart_disease': 0,
# ...

# %%
len(data_dict)
# Out:
# 5110

# %%
DB_NAME = "my_database"
COLLECTION_NAME = "my_collection"
COLLECTION_URL = "mongodb+srv://navinxqz:%23Navin%40477@cluster0.am2sy53.mongodb.net/?appName=Cluster0"

# %%
import pymongo
client = pymongo.MongoClient(COLLECTION_URL)
db_base = client[DB_NAME]
collection = db_base[COLLECTION_NAME]

# %% [markdown]
# ### Storing Data to MongoDB

# %%
# data push to mongodb
rec=collection.insert_many(data_dict)

# %% [markdown]
# ### Fetching Data from MongoDB

# %%
records=collection.find()

# %%
records

# %%
for i in records:
    print(i)
# Out:
# {'_id': ObjectId('69a493cbc741e7cfea0a3eba'), 'id': 9046, 'gender': 'Male', 'age': 67.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 228.69, 'bmi': 36.6, 'smoking_status': 'formerly smoked', 'stroke': 1}
# {'_id': ObjectId('69a493cbc741e7cfea0a3ebb'), 'id': 51676, 'gender': 'Female', 'age': 61.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 202.21, 'bmi': nan, 'smoking_status': 'never smoked', 'stroke': 1}
# {'_id': ObjectId('69a493cbc741e7cfea0a3ebc'), 'id': 31112, 'gender': 'Male', 'age': 80.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 105.92, 'bmi': 32.5, 'smoking_status': 'never smoked', 'stroke': 1}
# ...

# %%
df=pd.DataFrame(list(collection.find()))

# %%
df.head()
# Out:
#                         _id     id  gender   age  hypertension  heart_disease  \
# 0  69a493cbc741e7cfea0a3eba   9046    Male  67.0             0              1
# 1  69a493cbc741e7cfea0a3ebb  51676  Female  61.0             0              0
# 2  69a493cbc741e7cfea0a3ebc  31112    Male  80.0             0              1
# 3  69a493cbc741e7cfea0a3ebd  60182  Female  49.0             0              0
# 4  69a493cbc741e7cfea0a3ebe   1665  Female  79.0             1              0
#
#   ever_married      work_type Residence_type  avg_glucose_level   bmi  \
# 0          Yes        Private          Urban             228.69  36.6
# 1          Yes  Self-employed          Rural             202.21   NaN
# 2          Yes        Private          Rural             105.92  32.5
# 3          Yes        Private          Urban             171.23  34.4
# 4          Yes  Self-employed          Rural             174.12  24.0
#
#     smoking_status  stroke
# 0  formerly smoked       1
# ...

# %%
if "_id" in df.columns.tolist():
    df.drop(columns=["_id"], inplace=True)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.to_csv("D:\\Inception FSDS\\Inception-FSDS-classwork\\classwork\\Day26_Database\\healthcare-dataset-stroke-data_from_mongodb.csv", index=False)

# %% [markdown]
# ### Database remove

# %%
client.drop_database(DB_NAME)
