# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # Conditional Statements

# %%
email=input("Enter your email: ")
password=input("Enter your password: ")

if email == "u@gmail.com" and password == "123":
    print("Login successful!")
elif email != "u@gmail.com" and password == "123":
    print("Incorrect email!")
else:
    print("Incorrect password!")
# Out:
# Incorrect email!

# %%
num1=int(input("Enter first number: "))
num2=int(input("Enter second number: "))
num3=int(input("Enter third number: "))

# print(num1, num2, num3)
if num1<num2 and num1<num3:
    print(f"{num1} is the smallest number") #using f-string
elif num2<num1 and num2<num3:
    print(f"{num2} is the smallest number")
else:
    print(f"{num3} is the smallest number")
# Out:
# 6 is the smallest number

# %% [markdown]
# # Modules in Python
# 1. Buildins module/package
# 2. External module/package

# %% [markdown]
# # Buildins Module
# - Math
# - Keywords
# - random
# - datetime

# %%
import math
print(math.sqrt(16))
print(math.factorial(5))
# Out:
# 4.0
# 120

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import random
print(random.randint(1, 100))
# Out:
# 98

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2025-11-03 21:01:03.364273
