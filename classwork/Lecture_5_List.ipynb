# %% [markdown]
# # Characteristics of a List
# - Ordered
# - changeable/mutable
# - can be duplicates
# - can be nested
# - items can be accessed
# - Dynamic Size
# - Hetrogeneous
# - Speed of execution -> slow
# - more memory
# - multiple data type store

# %%
L=[1,2,3]

# %%
print(id(L))
print(id(L[0]))
# Out:
# 1884311119296
# 140706920182696
